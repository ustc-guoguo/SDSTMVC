# %%
import os
import numpy as np
import scipy.io as sio


data_root = '/mlx_devbox/users/wangminglei.04/playground/mvc/datasets/'
all_dataset = os.listdir(data_root)
for dataset in all_dataset:
    if dataset.endswith('.mat'):
        data_path = os.path.join(data_root, dataset)
        print(dataset)
        try:
            mat = sio.loadmat(data_path)
            print(mat.keys())
        except:
            print(f'Error loading {data_path}')
# Out:
# BBCSport2.mat
# dict_keys(['__header__', '__version__', '__globals__', 'fea', 'gt'])
# NUS-WIDE.mat
# dict_keys(['__header__', '__version__', '__globals__', 'Img', 'Txt', 'label'])
# Reuters_dim10.mat
# dict_keys(['__header__', '__version__', '__globals__', 'x_train', 'x_test', 'y_train', 'y_test'])
# HandWritten.mat
# dict_keys(['__header__', '__version__', '__globals__', 'X', 'Y', 'feanames', 'lenSmp'])
# 3sources.mat
# dict_keys(['__header__', '__version__', '__globals__', 'data', 'truelabel'])
# HW2sources.mat
# dict_keys(['__header__', '__version__', '__globals__', 'data', 'truelabel'])
# yale1.mat
# dict_keys(['__header__', '__version__', '__globals__', 'gt', 'X'])
# CiteSeer.mat
# dict_keys(['__header__', '__version__', '__globals__', 'fea', 'gt'])
# Hdigit.mat
# dict_keys(['__header__', '__version__', '__globals__', 'data', 'truelabel'])
# TwoMoon.mat
# dict_keys(['__header__', '__version__', '__globals__', 'X', 'y0'])
# ALOI_100.mat
# dict_keys(['__header__', '__version__', '__globals__', 'fea', 'gt'])
# Caltech101-20.mat
# dict_keys(['__header__', '__version__', '__globals__', 'Y', 'categories', 'cateset', 'data', 'feanames', 'lenSmp'])
# YaleB_first10.mat
# dict_keys(['__header__', '__version__', '__globals__', 'X2', 'X3', 'X1', 'gt'])
# 100leaves.mat
# dict_keys(['__header__', '__version__', '__globals__', 'truelabel', 'data'])
# Caltech101-all.mat
# dict_keys(['__header__', '__version__', '__globals__', 'categories', 'lenSmp', 'feanames', 'Y', 'X'])
# BBC.mat
# dict_keys(['__header__', '__version__', '__globals__', 'data', 'truelabel'])
# ORL.mat
# dict_keys(['__header__', '__version__', '__globals__', 'fea', 'gt'])
# Yale.mat
# dict_keys(['__header__', '__version__', '__globals__', 'fea', 'gt'])
# Deep Animal.mat
# dict_keys(['__header__', '__version__', '__globals__', 'gt', 'X'])
# ALOI_1K.mat
# dict_keys(['__header__', '__version__', '__globals__', 'fea', 'gt'])
# HW.mat
# dict_keys(['__header__', '__version__', '__globals__', 'data', 'truelabel'])
# Caltech101-7.mat
# dict_keys(['__header__', '__version__', '__globals__', 'Y', 'categories', 'cateset', 'data', 'feanames', 'lenSmp'])
# COIL20MV.mat
# dict_keys(['__header__', '__version__', '__globals__', 'gt', 'X'])
# Yale3.mat
# dict_keys(['__header__', '__version__', '__globals__', 'fea', 'gt'])
# BBCSport.mat
# dict_keys(['__header__', '__version__', '__globals__', 'data', 'truelabel'])
# Wiki.mat
# dict_keys(['__header__', '__version__', '__globals__', 'Img', 'Txt', 'label'])
# COIL20.mat
# Error loading /mlx_devbox/users/wangminglei.04/playground/mvc/datasets/COIL20.mat
# UCI_Digits.mat
# dict_keys(['__header__', '__version__', '__globals__', 'fea', 'gt'])
# still-2.mat
# dict_keys(['__header__', '__version__', '__globals__', 'gt', 'X'])
# ThreeRing.mat
# dict_keys(['__header__', '__version__', '__globals__', 'X', 'y0'])
# scene15.mat
# dict_keys(['__header__', '__version__', '__globals__', 'gt', 'X'])
# Reuters.mat
# dict_keys(['__header__', '__version__', '__globals__', 'fea', 'gt'])
# MNIST-USPS.mat
# dict_keys(['__header__', '__version__', '__globals__', 'X2', 'Y', 'X1'])
# LandUse-21.mat
# dict_keys(['__header__', '__version__', '__globals__', 'gt', 'X'])
# WebKB.mat
# dict_keys(['__header__', '__version__', '__globals__', 'data', 'truelabel'])
# MSRC-v1.mat
# dict_keys(['__header__', '__version__', '__globals__', 'X', 'Y'])
# UCI_3view.mat
# dict_keys(['__header__', '__version__', '__globals__', 'truth', 'data'])
# MSRCv1.mat
# dict_keys(['__header__', '__version__', '__globals__', 'X', 'Y'])
# Mfeat.mat
# dict_keys(['__header__', '__version__', '__globals__', 'data', 'truelabel'])
# ORL_mtv.mat
# dict_keys(['__header__', '__version__', '__globals__', 'gt', 'X'])
# MSRCV16view.mat
# dict_keys(['__header__', '__version__', '__globals__', 'X', 'Y'])
# scene.mat
# dict_keys(['__header__', '__version__', '__globals__', 'X', 'Y'])
# BDGP.mat
# dict_keys(['__header__', '__version__', '__globals__', 'X1', 'X2', 'Y'])
# flower17.mat
# dict_keys(['__header__', '__version__', '__globals__', 'distance_matrices', 'gt'])
# NGs.mat
# dict_keys(['__header__', '__version__', '__globals__', 'data', 'truelabel'])
# EYaleB10_mtv.mat
# dict_keys(['__header__', '__version__', '__globals__', 'X', 'gt'])
# cora.mat
# dict_keys(['__header__', '__version__', '__globals__', 'fea', 'gnd', 'note', 'nviews'])
